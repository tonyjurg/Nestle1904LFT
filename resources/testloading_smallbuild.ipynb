# %% [markdown]
# # Testload of first build (version 0.1.1)

# %%
from tf.app import use

# %%
# %load_ext autoreload
# %autoreload 2

# %%
GNT = use ("tonyjurg/n1904_lft", version="0.1.1", hoist=globals())
# Out:
# **Locating corpus resources ...**
# The requested app is not available offline
# 	C:/Users/tonyj/text-fabric-data/github/tonyjurg/n1904_lft/app not found
# rate limit is 5000 requests per hour, with 4866 left for this hour
# 	connecting to online GitHub repo tonyjurg/n1904_lft ... connected
# 	cannot find releases
# 	cannot find releases
# 	app/config.yaml...downloaded
# 	OK
# <b title="latest commit">app:</b> <span title="#9c761da0ee021c60101554f2caff626ce0bb2d85">~/text-fabric-data/github/tonyjurg/n1904_lft/app</span>
# The requested data is not available offline
# 	C:/Users/tonyj/text-fabric-data/github/tonyjurg/n1904_lft/tf/0.1.1 not found
# rate limit is 5000 requests per hour, with 4857 left for this hour
# 	connecting to online GitHub repo tonyjurg/n1904_lft ... connected
# 	cannot find releases
# 	cannot find releases
# 	tf/0.1.1/.tf...directory
# 		tf/0.1.1/.tf/3...directory
# 			tf/0.1.1/.tf/3/Rule.tfx...excluded
# 			tf/0.1.1/.tf/3/__boundary__.tfx...excluded
# ...

# %%
Search0 = '''
word
'''
Search0 = GNT.search(Search0)

GNT.show(Search0, start=1, end=3, condensed=True, extraFeatures={'word','word_in_verse','sentence-text','sentence_number','case', 'morph', 'ln', 'word', 'clauseType','cltype','type', 'role','discontinuous'})
# Out:
#   0.00s 464 results
# <p><b>file</b> <i>1</i>
# ...

# %%
# Out:
# ^C

# %%
TF.isLoaded()
# Out:
# Rule                 node (str) this is XML attribute rule
# __boundary__         computed
# __characters__       computed
# __levDown__          computed
# __levUp__            computed
# __levels__           computed
# __order__            computed
# __rank__             computed
# __sections__         computed
# __structure__        NOT LOADED
# after                node (str) this is XML attribute after
# articular            node (str) this is XML attribute articular
# book                 node (str) this is XML attribute book
# book_num             node (str) this is XML attribute book_num
# book_short           node (str) this is XML attribute book_short
# case                 node (str) this is XML attribute case
# ch                   node (str) the unicode character of a slot
# chapter              node (str) this is XML attribute chapter
# class                node (str) this is XML attribute class
# clauseType           node (str) this is XML attribute clauseType
# ...
