# %% [markdown]
# # Values frequency for selected features

# %%
# Loading the Text-Fabric code
# Note: it is assumed Text-Fabric is installed in your environment
from tf.fabric import Fabric
from tf.app import use

# %%
# load the N1904 app and data
N1904 = use ("tonyjurg/Nestle1904LFT", version="0.5", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv03=#f2eb5e2b0f8805ad720d91a5cb9e2aa2fdc6c99a offline under C:/Users/tonyj/text-fabric-data/github">~/text-fabric-data/github/tonyjurg/Nestle1904LFT/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/tonyjurg/Nestle1904LFT/tf/0.5 not found
# Status: latest release online <b>v03</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/tonyjurg/Nestle1904LFT/tf/0.5</span>
# ...

# %%
FeatureList=('bookshort','wgrole','wgtype', 'wgrole', 'degree','gn','junction','mood','nu','person','wgrule')
for Feature in FeatureList:
    if Feature=='otype': break # this feature needs to be skipped.
    print ('Feature:',Feature,'\n\n\t value\t frequency')
    FeatureFrequenceLists=Fs(Feature).freqList()
    for item, freq in FeatureFrequenceLists:
        print ('\t',item,'\t',freq)

    print ('\n')
# Out:
# Feature: bookshort
#
# 	 value	 frequency
# 	 Luke 	 19457
# 	 Acts 	 18394
# 	 Matt 	 18300
# 	 John 	 15644
# 	 Mark 	 11278
# 	 Rev 	 9833
# 	 Rom 	 7101
# 	 1Cor 	 6821
# 	 Heb 	 4956
# 	 2Cor 	 4470
# 	 Eph 	 2420
# 	 Gal 	 2229
# 	 1John 	 2137
# 	 Jas 	 1740
# 	 1Pet 	 1677
# 	 Phil 	 1631
# 	 1Tim 	 1589
# 	 Col 	 1576
# 	 1Thess 	 1474
# 	 2Tim 	 1238
# 	 2Pet 	 1099
# 	 2Thess 	 823
# 	 Titus 	 659
# 	 Jude 	 458
# 	 Phlm 	 336
# 	 2John 	 246
# 	 3John 	 220
#
#
# Feature: wgrole
#
# 	 value	 frequency
# 	  	 77251
# 	 adv 	 16710
# 	 o 	 9329
# 	 s 	 6710
# 	 p 	 1770
# 	 io 	 702
# 	 v 	 405
# 	 aux 	 360
# 	 o2 	 171
# 	 topic 	 25
# 	 vc 	 10
# 	 ellipsis 	 2
# 	 err_clause-complex-met-no-conditionsClCl2 	 1
# 	 tail 	 1
#
#
# Feature: wgtype
#
# 	 value	 frequency
# 	  	 100949
# 	 group 	 9699
# 	 apposition 	 2799
#
#
# Feature: wgrole
#
# 	 value	 frequency
# 	  	 77251
# 	 adv 	 16710
# 	 o 	 9329
# 	 s 	 6710
# 	 p 	 1770
# 	 io 	 702
# 	 v 	 405
# 	 aux 	 360
# ...

# %%
## Value list of selected features
